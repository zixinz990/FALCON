# %%
import numpy as np
import joblib

# accad = "/home/zixin/Dev/FALCON/humanoidverse/data/motions/g1_29dof/v1/accad_all.pkl"
# accad_data = joblib.load(accad)
# accad_data_sample = accad_data['0-ACCAD_Female1Walking_c3d_B13 - walk turn right (45)_poses']
# print(accad_data_sample['dof'])

# %%
cmu_mocap = "/home/zixin/Dev/FALCON/humanoidverse/data/motions/g1_29dof/v1/cmu_all.pkl"
cmu_mocap_data = joblib.load(cmu_mocap)
cmu_mocap_num_data = len(cmu_mocap_data.keys())
print(cmu_mocap_num_data)
# Out:
# 1980

# %%
# accad_female1_walking_N = "/home/zixin/Dev/FALCON/humanoidverse/data/motions/g1_29dof/v1/accad_female1_walking_N.pkl"
# accad_female1_walking_N_data = joblib.load(accad_female1_walking_N)
# accad_female1_walking_N_data_sample = accad_female1_walking_N_data['B13_-_walk_turn_right_(45)_stageii']
# print(accad_female1_walking_N_data_sample['dof'])
